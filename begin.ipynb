# %%
a,b = 10,20
#substraction
print("substraction is" ,b-a)
#addition
print("addition is",b+a)
print("multiplication is",b*a)
print("division is",b/a)
print("cube is",b**a)
# Out:
# substraction is 10
# addition is 30
# multiplication is 200
# division is 2.0
# cube is 10240000000000

# %% [markdown]
# DATA TYPES
#
# Every value in Python has a datatype. Since everything is an object in Python programming, data types are actually classes and variables are instance (object) of these classes.
#
# Basically, we have 4 data types - Numeric, Boolean, String and Sequence

# %%
a=5  #we use type function to check which class the variable or the value belongs to...
print(a,"is of type",type(a))
# Out:
# 5 is of type <class 'int'>

# %%
a=4.8
print(a,"is of  type",type(a))
# Out:
# 4.8 is of  type <class 'float'>

# %%
a= "rahul"
print(a,"is of type",type(a))
# Out:
# rahul is of type <class 'str'>

# %%
a=10  #the isinstance() function to check if an object belongs to a particular class.
isinstance(a,int)
# Out:
# True

# %%
a= "sangolli"
isinstance(a,str)
# Out:
# True

# %%
isinstance(a,int)
# Out:
# False

# %% [markdown]
# list

# %%
a= 10,2.5,"rahul"
print(a)
print(a[2]) #this is called indexing, printing the 2nd index position of a variable
# Out:
# (10, 2.5, 'rahul')
# rahul

# %% [markdown]
# dictionary

# %%
z= {'a':"rahul",'b':"data science"}
print(z)
print(z['a'])
# Out:
# {'a': 'rahul', 'b': 'data science'}
# rahul

# %%
z['a']=["buzza"]  #adding a new value corresponding to the key
print(z)
# Out:
# {'a': ['buzza'], 'b': 'data science'}

# %%
z['t']=["tilak"] #adding a new key value pair
print(z)
# Out:
# {'a': ['buzza'], 'b': 'data science', 't': ['tilak']}
